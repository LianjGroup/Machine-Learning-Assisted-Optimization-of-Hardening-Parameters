# %%
################################
##                            ##
##      2 hidden layers       ##
##                            ##
################################

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
yieldingIndices = {'NDBR50': 200, 'NDBR20': 200, 'NDBR6': 200, 'CHD6': 1200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a simple neural network model
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, output_size)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 256  # Number of units in the first hidden layer
hidden_size2 = 256  # Number of units in the second hidden layer
output_size = 7  # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, output_size)

# Define a loss function (mean squared error) and an optimizer (e.g., Adam)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 1000

# Lists to store loss values for each geometry
loss_lists = {geometry: [] for geometry in geometries}

for geometry in geometries:
    num_samples = yieldingIndices[geometry]
    X_sample = torch.tensor(X_data[geometry], dtype=torch.float32)[:num_samples]
    Y_sample = torch.tensor(Y_data, dtype=torch.float32)[:num_samples]

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss
        loss = criterion(outputs, Y_sample)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_lists[geometry].append(loss.item())

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Plot the loss for each geometry in a single graph
for geometry in geometries:
    plt.plot(loss_lists[geometry], label=f'Geometry: {geometry}')

plt.xlabel('Number of Epochs')
plt.ylabel('Value of Loss')
plt.legend()
plt.title('Training Loss for Different Geometries over 1000 Epochs')
plt.show()

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)
plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/1000], Loss: 42443.4766
# Geometry: NDBR50, Epoch [200/1000], Loss: 42377.3984
# Geometry: NDBR50, Epoch [300/1000], Loss: 42305.6992
# Geometry: NDBR50, Epoch [400/1000], Loss: 42326.3438
# Geometry: NDBR50, Epoch [500/1000], Loss: 42039.4766
# Geometry: NDBR50, Epoch [600/1000], Loss: 41857.3984
# Geometry: NDBR50, Epoch [700/1000], Loss: 41625.3164
# Geometry: NDBR50, Epoch [800/1000], Loss: 41332.8633
# Geometry: NDBR50, Epoch [900/1000], Loss: 41064.3477
# Geometry: NDBR50, Epoch [1000/1000], Loss: 40605.7070
# Geometry: NDBR20, Epoch [100/1000], Loss: 38707.1523
# Geometry: NDBR20, Epoch [200/1000], Loss: 41465.3867
# Geometry: NDBR20, Epoch [300/1000], Loss: 37765.9141
# Geometry: NDBR20, Epoch [400/1000], Loss: 36948.1016
# Geometry: NDBR20, Epoch [500/1000], Loss: 35963.4922
# Geometry: NDBR20, Epoch [600/1000], Loss: 35778.4922
# Geometry: NDBR20, Epoch [700/1000], Loss: 34571.0469
# Geometry: NDBR20, Epoch [800/1000], Loss: 34983.6016
# Geometry: NDBR20, Epoch [900/1000], Loss: 33796.2461
# Geometry: NDBR20, Epoch [1000/1000], Loss: 33560.5156
# Geometry: NDBR6, Epoch [100/1000], Loss: 33338.1758
# Geometry: NDBR6, Epoch [200/1000], Loss: 32247.0977
# Geometry: NDBR6, Epoch [300/1000], Loss: 31983.8281
# Geometry: NDBR6, Epoch [400/1000], Loss: 30858.3516
# Geometry: NDBR6, Epoch [500/1000], Loss: 31929.0762
# Geometry: NDBR6, Epoch [600/1000], Loss: 30391.3379
# Geometry: NDBR6, Epoch [700/1000], Loss: 28409.0137
# Geometry: NDBR6, Epoch [800/1000], Loss: 27250.1680
# Geometry: NDBR6, Epoch [900/1000], Loss: 26253.0762
# Geometry: NDBR6, Epoch [1000/1000], Loss: 25029.8008
# Geometry: CHD6, Epoch [100/1000], Loss: 135297.8750
# Geometry: CHD6, Epoch [200/1000], Loss: 134939.2500
# Geometry: CHD6, Epoch [300/1000], Loss: 134690.0625
# Geometry: CHD6, Epoch [400/1000], Loss: 134440.0312
# Geometry: CHD6, Epoch [500/1000], Loss: 134199.7812
# Geometry: CHD6, Epoch [600/1000], Loss: 133954.1719
# Geometry: CHD6, Epoch [700/1000], Loss: 133716.8438
# Geometry: CHD6, Epoch [800/1000], Loss: 133658.3125
# Geometry: CHD6, Epoch [900/1000], Loss: 133464.2031
# Geometry: CHD6, Epoch [1000/1000], Loss: 133300.5312
# Predicted parameters for geometry NDBR50:
# [-2.0908002853393555, 821.4876098632812, -0.3943985402584076, 1.1756755113601685, 798.8353271484375, 437.2702941894531, 447.8891906738281]
# Predicted parameters for geometry NDBR20:
# [-2.4854519367218018, 794.5040893554688, -0.9185742139816284, 1.5916281938552856, 775.7066040039062, 422.9457702636719, 436.6478576660156]
# Predicted parameters for geometry NDBR6:
# [-2.024695873260498, 827.9898681640625, -0.2886079251766205, 1.0796643495559692, 804.4560546875, 440.7032165527344, 450.6863708496094]
# Predicted parameters for geometry CHD6:
# [-2.0211970806121826, 828.40625, -0.2825697362422943, 1.073574185371399, 804.8152465820312, 440.92205810546875, 450.8662109375]

# %%
################################
##                            ##
##      4 hidden layers       ##
##                            ##
################################


import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
yieldingIndices = {'NDBR50': 200, 'NDBR20': 200, 'NDBR6': 200, 'CHD6': 1200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a simple neural network model
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.relu4 = nn.ReLU()
        self.fc5 = nn.Linear(hidden_size4, output_size)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.fc5(x)
        return x

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 256  # Number of units in the first hidden layer
hidden_size2 = 256  # Number of units in the second hidden layer
hidden_size3 = 128  # Number of units in the third hidden layer
hidden_size4 = 64   # Number of units in the fourth hidden layer
output_size = 7    # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size)


# Define a loss function (mean squared error) and an optimizer (e.g., Adam)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Training loop
num_epochs = 10000

# Lists to store loss values for each geometry
loss_lists = {geometry: [] for geometry in geometries}

for geometry in geometries:
    num_samples = min(yieldingIndices[geometry], len(Y_data))
    X_sample = torch.tensor(X_data[geometry][:num_samples], dtype=torch.float32)
    Y_sample = torch.tensor(Y_data[:num_samples], dtype=torch.float32)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss
        loss = criterion(outputs, Y_sample)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_lists[geometry].append(loss.item())

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Plot the loss for each geometry in a single graph
for geometry in geometries:
    plt.plot(loss_lists[geometry], label=f'Geometry: {geometry}')

plt.xlabel('Number of Epochs')
plt.ylabel('Value of Loss')
plt.legend()
plt.title('Training Loss for Different Geometries over 1000 Epochs')
plt.show()

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)

plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/10000], Loss: 42334.4844
# Geometry: NDBR50, Epoch [200/10000], Loss: 42321.9648
# Geometry: NDBR50, Epoch [300/10000], Loss: 42010.0625
# Geometry: NDBR50, Epoch [400/10000], Loss: 39448.9805
# Geometry: NDBR50, Epoch [500/10000], Loss: 39355.5898
# Geometry: NDBR50, Epoch [600/10000], Loss: 39228.1875
# Geometry: NDBR50, Epoch [700/10000], Loss: 39051.6016
# Geometry: NDBR50, Epoch [800/10000], Loss: 38800.0195
# Geometry: NDBR50, Epoch [900/10000], Loss: 38491.4062
# Geometry: NDBR50, Epoch [1000/10000], Loss: 44506.7266
# Geometry: NDBR50, Epoch [1100/10000], Loss: 38395.4844
# Geometry: NDBR50, Epoch [1200/10000], Loss: 37999.0156
# Geometry: NDBR50, Epoch [1300/10000], Loss: 37525.8125
# Geometry: NDBR50, Epoch [1400/10000], Loss: 36258.0156
# Geometry: NDBR50, Epoch [1500/10000], Loss: 35375.6172
# Geometry: NDBR50, Epoch [1600/10000], Loss: 38422.8867
# Geometry: NDBR50, Epoch [1700/10000], Loss: 38150.9570
# Geometry: NDBR50, Epoch [1800/10000], Loss: 37787.0938
# Geometry: NDBR50, Epoch [1900/10000], Loss: 37550.8047
# Geometry: NDBR50, Epoch [2000/10000], Loss: 36826.6914
# Geometry: NDBR50, Epoch [2100/10000], Loss: 36392.4492
# Geometry: NDBR50, Epoch [2200/10000], Loss: 34674.9531
# Geometry: NDBR50, Epoch [2300/10000], Loss: 35431.2734
# Geometry: NDBR50, Epoch [2400/10000], Loss: 33890.4492
# Geometry: NDBR50, Epoch [2500/10000], Loss: 41782.0664
# Geometry: NDBR50, Epoch [2600/10000], Loss: 35810.1758
# Geometry: NDBR50, Epoch [2700/10000], Loss: 34213.0039
# Geometry: NDBR50, Epoch [2800/10000], Loss: 30390.4512
# Geometry: NDBR50, Epoch [2900/10000], Loss: 29947.3262
# Geometry: NDBR50, Epoch [3000/10000], Loss: 27060.3320
# Geometry: NDBR50, Epoch [3100/10000], Loss: 37859.7109
# Geometry: NDBR50, Epoch [3200/10000], Loss: 29865.2539
# Geometry: NDBR50, Epoch [3300/10000], Loss: 8283.7188
# Geometry: NDBR50, Epoch [3400/10000], Loss: 7957.9834
# Geometry: NDBR50, Epoch [3500/10000], Loss: 6145.8242
# Geometry: NDBR50, Epoch [3600/10000], Loss: 5554.1221
# Geometry: NDBR50, Epoch [3700/10000], Loss: 5387.6616
# Geometry: NDBR50, Epoch [3800/10000], Loss: 4844.4009
# Geometry: NDBR50, Epoch [3900/10000], Loss: 4290.5308
# Geometry: NDBR50, Epoch [4000/10000], Loss: 3781.9521
# Geometry: NDBR50, Epoch [4100/10000], Loss: 3353.0295
# Geometry: NDBR50, Epoch [4200/10000], Loss: 3002.7163
# Geometry: NDBR50, Epoch [4300/10000], Loss: 2719.7490
# Geometry: NDBR50, Epoch [4400/10000], Loss: 2434.0488
# Geometry: NDBR50, Epoch [4500/10000], Loss: 2182.4768
# Geometry: NDBR50, Epoch [4600/10000], Loss: 2215.7183
# Geometry: NDBR50, Epoch [4700/10000], Loss: 1760.3311
# Geometry: NDBR50, Epoch [4800/10000], Loss: 26098.2910
# Geometry: NDBR50, Epoch [4900/10000], Loss: 20562.1836
# Geometry: NDBR50, Epoch [5000/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5100/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5200/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5300/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5400/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [5500/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [5600/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5700/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [5800/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [5900/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [6000/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [6100/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [6200/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [6300/10000], Loss: 20561.3184
# Geometry: NDBR50, Epoch [6400/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [6500/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [6600/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [6700/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [6800/10000], Loss: 20562.3496
# Geometry: NDBR50, Epoch [6900/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [7000/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [7100/10000], Loss: 20562.9551
# Geometry: NDBR50, Epoch [7200/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [7300/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [7400/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [7500/10000], Loss: 20561.4043
# Geometry: NDBR50, Epoch [7600/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [7700/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [7800/10000], Loss: 20561.3086
# Geometry: NDBR50, Epoch [7900/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8000/10000], Loss: 20564.8691
# Geometry: NDBR50, Epoch [8100/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8200/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8300/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8400/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8500/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [8600/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [8700/10000], Loss: 20561.8691
# Geometry: NDBR50, Epoch [8800/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [8900/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [9000/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [9100/10000], Loss: 20561.3164
# Geometry: NDBR50, Epoch [9200/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [9300/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [9400/10000], Loss: 20561.3047
# Geometry: NDBR50, Epoch [9500/10000], Loss: 20561.5684
# Geometry: NDBR50, Epoch [9600/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [9700/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [9800/10000], Loss: 20564.1094
# Geometry: NDBR50, Epoch [9900/10000], Loss: 20561.3066
# Geometry: NDBR50, Epoch [10000/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [100/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [200/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [300/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [400/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [500/10000], Loss: 20561.3203
# Geometry: NDBR20, Epoch [600/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [700/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [800/10000], Loss: 20561.3203
# Geometry: NDBR20, Epoch [900/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [1000/10000], Loss: 20561.3105
# Geometry: NDBR20, Epoch [1100/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [1200/10000], Loss: 20561.3086
# Geometry: NDBR20, Epoch [1300/10000], Loss: 20561.7090
# Geometry: NDBR20, Epoch [1400/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [1500/10000], Loss: 20561.4082
# Geometry: NDBR20, Epoch [1600/10000], Loss: 20561.3145
# Geometry: NDBR20, Epoch [1700/10000], Loss: 20562.9121
# Geometry: NDBR20, Epoch [1800/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [1900/10000], Loss: 20561.5879
# Geometry: NDBR20, Epoch [2000/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [2100/10000], Loss: 20561.3691
# Geometry: NDBR20, Epoch [2200/10000], Loss: 20561.3281
# Geometry: NDBR20, Epoch [2300/10000], Loss: 20561.4023
# Geometry: NDBR20, Epoch [2400/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [2500/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [2600/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [2700/10000], Loss: 20562.2207
# Geometry: NDBR20, Epoch [2800/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [2900/10000], Loss: 20561.3086
# Geometry: NDBR20, Epoch [3000/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [3100/10000], Loss: 20564.0664
# Geometry: NDBR20, Epoch [3200/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [3300/10000], Loss: 20561.3125
# Geometry: NDBR20, Epoch [3400/10000], Loss: 20561.3105
# Geometry: NDBR20, Epoch [3500/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [3600/10000], Loss: 20561.9199
# Geometry: NDBR20, Epoch [3700/10000], Loss: 20561.3203
# Geometry: NDBR20, Epoch [3800/10000], Loss: 20561.3086
# Geometry: NDBR20, Epoch [3900/10000], Loss: 20570.4688
# Geometry: NDBR20, Epoch [4000/10000], Loss: 20561.3145
# Geometry: NDBR20, Epoch [4100/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [4200/10000], Loss: 20561.3281
# Geometry: NDBR20, Epoch [4300/10000], Loss: 20561.3379
# Geometry: NDBR20, Epoch [4400/10000], Loss: 20561.3730
# Geometry: NDBR20, Epoch [4500/10000], Loss: 20561.3574
# Geometry: NDBR20, Epoch [4600/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [4700/10000], Loss: 20561.5703
# Geometry: NDBR20, Epoch [4800/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [4900/10000], Loss: 20561.6699
# Geometry: NDBR20, Epoch [5000/10000], Loss: 20561.3125
# Geometry: NDBR20, Epoch [5100/10000], Loss: 20562.6055
# Geometry: NDBR20, Epoch [5200/10000], Loss: 20561.3320
# Geometry: NDBR20, Epoch [5300/10000], Loss: 20561.3906
# Geometry: NDBR20, Epoch [5400/10000], Loss: 20561.3184
# Geometry: NDBR20, Epoch [5500/10000], Loss: 20561.3477
# Geometry: NDBR20, Epoch [5600/10000], Loss: 20561.3086
# Geometry: NDBR20, Epoch [5700/10000], Loss: 20561.3184
# Geometry: NDBR20, Epoch [5800/10000], Loss: 20561.3164
# Geometry: NDBR20, Epoch [5900/10000], Loss: 20561.5957
# Geometry: NDBR20, Epoch [6000/10000], Loss: 20561.3145
# Geometry: NDBR20, Epoch [6100/10000], Loss: 20561.3418
# Geometry: NDBR20, Epoch [6200/10000], Loss: 20561.3164
# Geometry: NDBR20, Epoch [6300/10000], Loss: 20561.3105
# Geometry: NDBR20, Epoch [6400/10000], Loss: 20561.3770
# Geometry: NDBR20, Epoch [6500/10000], Loss: 20561.3301
# Geometry: NDBR20, Epoch [6600/10000], Loss: 20561.3242
# Geometry: NDBR20, Epoch [6700/10000], Loss: 20562.2441
# Geometry: NDBR20, Epoch [6800/10000], Loss: 20561.3711
# Geometry: NDBR20, Epoch [6900/10000], Loss: 20561.3340
# Geometry: NDBR20, Epoch [7000/10000], Loss: 20561.4023
# Geometry: NDBR20, Epoch [7100/10000], Loss: 20561.3184
# Geometry: NDBR20, Epoch [7200/10000], Loss: 20561.4707
# Geometry: NDBR20, Epoch [7300/10000], Loss: 20561.7754
# Geometry: NDBR20, Epoch [7400/10000], Loss: 20561.4023
# Geometry: NDBR20, Epoch [7500/10000], Loss: 20567.0723
# Geometry: NDBR20, Epoch [7600/10000], Loss: 20561.3887
# Geometry: NDBR20, Epoch [7700/10000], Loss: 20561.3477
# Geometry: NDBR20, Epoch [7800/10000], Loss: 20563.2734
# Geometry: NDBR20, Epoch [7900/10000], Loss: 20561.4863
# Geometry: NDBR20, Epoch [8000/10000], Loss: 20561.5508
# Geometry: NDBR20, Epoch [8100/10000], Loss: 20561.3535
# Geometry: NDBR20, Epoch [8200/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [8300/10000], Loss: 20561.3535
# Geometry: NDBR20, Epoch [8400/10000], Loss: 20561.4746
# Geometry: NDBR20, Epoch [8500/10000], Loss: 20561.4492
# Geometry: NDBR20, Epoch [8600/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [8700/10000], Loss: 20561.7266
# Geometry: NDBR20, Epoch [8800/10000], Loss: 20561.3262
# Geometry: NDBR20, Epoch [8900/10000], Loss: 20561.3047
# Geometry: NDBR20, Epoch [9000/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [9100/10000], Loss: 20561.5254
# Geometry: NDBR20, Epoch [9200/10000], Loss: 20561.3145
# Geometry: NDBR20, Epoch [9300/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [9400/10000], Loss: 20561.3066
# Geometry: NDBR20, Epoch [9500/10000], Loss: 20561.3164
# Geometry: NDBR20, Epoch [9600/10000], Loss: 20561.3086
# Geometry: NDBR20, Epoch [9700/10000], Loss: 20563.8965
# Geometry: NDBR20, Epoch [9800/10000], Loss: 20561.4473
# Geometry: NDBR20, Epoch [9900/10000], Loss: 20561.3105
# Geometry: NDBR20, Epoch [10000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [100/10000], Loss: 37075.6055
# Geometry: NDBR6, Epoch [200/10000], Loss: 35531.6992
# Geometry: NDBR6, Epoch [300/10000], Loss: 35984.1680
# Geometry: NDBR6, Epoch [400/10000], Loss: 34912.8633
# Geometry: NDBR6, Epoch [500/10000], Loss: 37250.8945
# Geometry: NDBR6, Epoch [600/10000], Loss: 36734.0859
# Geometry: NDBR6, Epoch [700/10000], Loss: 36328.9766
# Geometry: NDBR6, Epoch [800/10000], Loss: 35225.1250
# Geometry: NDBR6, Epoch [900/10000], Loss: 34696.9531
# Geometry: NDBR6, Epoch [1000/10000], Loss: 38214.3672
# Geometry: NDBR6, Epoch [1100/10000], Loss: 35182.7109
# Geometry: NDBR6, Epoch [1200/10000], Loss: 34471.6172
# Geometry: NDBR6, Epoch [1300/10000], Loss: 33282.0586
# Geometry: NDBR6, Epoch [1400/10000], Loss: 31369.3848
# Geometry: NDBR6, Epoch [1500/10000], Loss: 32056.1680
# Geometry: NDBR6, Epoch [1600/10000], Loss: 28039.8340
# Geometry: NDBR6, Epoch [1700/10000], Loss: 33412.9609
# Geometry: NDBR6, Epoch [1800/10000], Loss: 32098.0996
# Geometry: NDBR6, Epoch [1900/10000], Loss: 30065.2305
# Geometry: NDBR6, Epoch [2000/10000], Loss: 68038.8594
# Geometry: NDBR6, Epoch [2100/10000], Loss: 33554.7383
# Geometry: NDBR6, Epoch [2200/10000], Loss: 32566.1348
# Geometry: NDBR6, Epoch [2300/10000], Loss: 31084.4082
# Geometry: NDBR6, Epoch [2400/10000], Loss: 28801.3594
# Geometry: NDBR6, Epoch [2500/10000], Loss: 33641.6445
# Geometry: NDBR6, Epoch [2600/10000], Loss: 32390.9434
# Geometry: NDBR6, Epoch [2700/10000], Loss: 30390.5430
# Geometry: NDBR6, Epoch [2800/10000], Loss: 20767.4395
# Geometry: NDBR6, Epoch [2900/10000], Loss: 20562.5625
# Geometry: NDBR6, Epoch [3000/10000], Loss: 20561.8125
# Geometry: NDBR6, Epoch [3100/10000], Loss: 20561.5449
# Geometry: NDBR6, Epoch [3200/10000], Loss: 20561.4277
# Geometry: NDBR6, Epoch [3300/10000], Loss: 20561.3730
# Geometry: NDBR6, Epoch [3400/10000], Loss: 20561.3457
# Geometry: NDBR6, Epoch [3500/10000], Loss: 20561.3281
# Geometry: NDBR6, Epoch [3600/10000], Loss: 20561.3184
# Geometry: NDBR6, Epoch [3700/10000], Loss: 20561.3125
# Geometry: NDBR6, Epoch [3800/10000], Loss: 20561.3105
# Geometry: NDBR6, Epoch [3900/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4000/10000], Loss: 20561.3086
# Geometry: NDBR6, Epoch [4100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4200/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4500/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [4800/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [4900/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [5000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5200/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5500/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5800/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [5900/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6200/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6500/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6800/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [6900/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7200/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [7300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7500/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7800/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [7900/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8200/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [8300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8500/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [8600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8800/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [8900/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9000/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9100/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9200/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [9300/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9400/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9500/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9600/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9700/10000], Loss: 20561.3066
# Geometry: NDBR6, Epoch [9800/10000], Loss: 20561.3047
# Geometry: NDBR6, Epoch [9900/10000], Loss: 20561.3086
# Geometry: NDBR6, Epoch [10000/10000], Loss: 20561.3066
# Geometry: CHD6, Epoch [100/10000], Loss: 111748.0781
# Geometry: CHD6, Epoch [200/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [300/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [400/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [500/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [800/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1000/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1100/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1200/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [1300/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1400/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [1500/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [1600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [1900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [2000/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2100/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [2200/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [2300/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2400/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [2500/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2600/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2700/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2800/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [2900/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [3000/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [3100/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [3200/10000], Loss: 111748.4844
# Geometry: CHD6, Epoch [3300/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [3400/10000], Loss: 111747.8594
# Geometry: CHD6, Epoch [3500/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [3600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [3700/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [3800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [3900/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [4000/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [4100/10000], Loss: 111748.0391
# Geometry: CHD6, Epoch [4200/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [4300/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [4400/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [4500/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [4600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [4700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [4800/10000], Loss: 111748.0078
# Geometry: CHD6, Epoch [4900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [5000/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [5100/10000], Loss: 111747.8672
# Geometry: CHD6, Epoch [5200/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [5300/10000], Loss: 111747.8594
# Geometry: CHD6, Epoch [5400/10000], Loss: 111747.8750
# Geometry: CHD6, Epoch [5500/10000], Loss: 111748.1406
# Geometry: CHD6, Epoch [5600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [5700/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [5800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [5900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [6000/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [6100/10000], Loss: 111747.9766
# Geometry: CHD6, Epoch [6200/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [6300/10000], Loss: 111748.4688
# Geometry: CHD6, Epoch [6400/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [6500/10000], Loss: 111753.3750
# Geometry: CHD6, Epoch [6600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [6700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [6800/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [6900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7000/10000], Loss: 111747.8750
# Geometry: CHD6, Epoch [7100/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [7200/10000], Loss: 111752.5859
# Geometry: CHD6, Epoch [7300/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7400/10000], Loss: 111747.8672
# Geometry: CHD6, Epoch [7500/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [7900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8000/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [8100/10000], Loss: 111747.9453
# Geometry: CHD6, Epoch [8200/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8300/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [8400/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8500/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8600/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8700/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [8800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [8900/10000], Loss: 111751.9688
# Geometry: CHD6, Epoch [9000/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9100/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9200/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9300/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9400/10000], Loss: 111747.8516
# Geometry: CHD6, Epoch [9500/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9600/10000], Loss: 111747.8672
# Geometry: CHD6, Epoch [9700/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9800/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [9900/10000], Loss: 111747.8438
# Geometry: CHD6, Epoch [10000/10000], Loss: 111747.8516
# Predicted parameters for geometry NDBR50:
# [0.007100880146026611, 1082.105712890625, 0.5171384215354919, 0.23032239079475403, 1017.9251708984375, 490.91802978515625, 475.7492370605469]
# Predicted parameters for geometry NDBR20:
# [-1.1203272342681885, 896.9024658203125, 1.4514856338500977, -0.4925646483898163, 843.9207153320312, 410.9295654296875, 395.0977783203125]
# Predicted parameters for geometry NDBR6:
# [0.3633020520210266, 1139.6580810546875, 0.22155660390853882, 0.45891812443733215, 1071.970947265625, 515.7706909179688, 500.8094787597656]
# Predicted parameters for geometry CHD6:
# [0.38710957765579224, 1143.528564453125, 0.2018079161643982, 0.47419217228889465, 1075.606201171875, 517.4421997070312, 502.4949035644531]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
yieldingIndices = {'NDBR50': 20200, 'NDBR20': 20200, 'NDBR6': 20200, 'CHD6': 20200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a simple neural network model
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.relu4 = nn.ReLU()
        self.fc5 = nn.Linear(hidden_size4, output_size)
        self.relu_out = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.fc5(x)
        x = self.relu_out(x)
        return x

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 256  # Number of units in the first hidden layer
hidden_size2 = 256  # Number of units in the second hidden layer
hidden_size3 = 128  # Number of units in the third hidden layer
hidden_size4 = 128   # Number of units in the fourth hidden layer
output_size = 7    # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size)

# Define a loss function (mean squared error) and an optimizer (e.g., Adam)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Training loop
num_epochs = 100

for geometry in geometries:
    num_samples = min(yieldingIndices[geometry], len(Y_data))
    X_sample = torch.tensor(X_data[geometry][:num_samples], dtype=torch.float32)
    Y_sample = torch.tensor(Y_data[:num_samples], dtype=torch.float32)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss
        loss = criterion(outputs, Y_sample)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Save the trained model
torch.save(model.state_dict(), 'trained_model.pth')

# Load the trained model for prediction
model.load_state_dict(torch.load('trained_model.pth'))
model.eval()  # Set the model to evaluation mode

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)

plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/100], Loss: 433864.6875
# Geometry: NDBR20, Epoch [100/100], Loss: 433755.0938
# Geometry: NDBR6, Epoch [100/100], Loss: 403079.3125
# Geometry: CHD6, Epoch [100/100], Loss: 267801.9688
# Predicted parameters for geometry NDBR50:
# [0.0, 5.192399024963379, 0.0, 0.0, 26.11055564880371, 36.11531066894531, 0.3917194604873657]
# Predicted parameters for geometry NDBR20:
# [0.0, 1.9045193195343018, 0.0, 0.0, 7.459428787231445, 9.76799488067627, 0.678534746170044]
# Predicted parameters for geometry NDBR6:
# [0.0, 7.1581807136535645, 0.0, 0.0, 34.05351638793945, 49.01397705078125, 0.0]
# Predicted parameters for geometry CHD6:
# [0.0, 7.342813491821289, 0.0, 0.0, 34.62731170654297, 50.05598068237305, 0.0]
