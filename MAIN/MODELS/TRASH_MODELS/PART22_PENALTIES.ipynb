# %%
################################
##                            ##
##         dying relu         ##
##                            ##
################################

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
dataPoints = {'NDBR50': 20200, 'NDBR20': 20200, 'NDBR6': 20200, 'CHD6': 20200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a custom neural network model with regularization
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.relu4 = nn.ReLU()
        self.fc5 = nn.Linear(hidden_size4, output_size)
        self.relu_out = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.fc5(x)
        x = self.relu_out(x) 
        return x


# Custom loss function with regularization
class CustomMSELoss(nn.Module):
    def __init__(self, lambda_reg):
        super(CustomMSELoss, self).__init__()
        self.lambda_reg = lambda_reg

    def forward(self, outputs, targets, target_values):
        mse_loss = nn.MSELoss()(outputs, targets)
        reg_loss = torch.mean((outputs - target_values) ** 2)
        return mse_loss + self.lambda_reg * reg_loss

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 64  # Number of units in the first hidden layer
hidden_size2 = 64  # Number of units in the second hidden layer
hidden_size3 = 64  # Number of units in the second hidden layer
hidden_size4 = 64  # Number of units in the second hidden layer
output_size = 7    # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size)


# Define a loss function (custom MSE loss with regularization) and an optimizer (e.g., Adam)
criterion = CustomMSELoss(lambda_reg=0.01)  # Adjust lambda_reg as needed
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 1000

target_values = torch.tensor([0.007100880146026611, 1082.105712890625, 0.5171384215354919, 
                              0.23032239079475403, 1017.9251708984375, 490.91802978515625, 475.7492370605469], 
                             dtype=torch.float32)

for geometry in geometries:
    num_samples = min(dataPoints[geometry], len(Y_data))
    X_sample = torch.tensor(X_data[geometry][:num_samples], dtype=torch.float32)
    Y_sample = torch.tensor(Y_data[:num_samples], dtype=torch.float32)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss with regularization
        loss = criterion(outputs, Y_sample, target_values)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Save the trained model
torch.save(model.state_dict(), 'trained_model.pth')

# Load the trained model for prediction
model.load_state_dict(torch.load('trained_model.pth'))
model.eval()  # Set the model to evaluation mode

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)

plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/1000], Loss: 150623.2031
# Geometry: NDBR50, Epoch [200/1000], Loss: 150569.1562
# Geometry: NDBR50, Epoch [300/1000], Loss: 150511.7656
# Geometry: NDBR50, Epoch [400/1000], Loss: 150446.0312
# Geometry: NDBR50, Epoch [500/1000], Loss: 150369.0938
# Geometry: NDBR50, Epoch [600/1000], Loss: 150346.9062
# Geometry: NDBR50, Epoch [700/1000], Loss: 150246.6250
# Geometry: NDBR50, Epoch [800/1000], Loss: 150161.4844
# Geometry: NDBR50, Epoch [900/1000], Loss: 149610.8750
# Geometry: NDBR50, Epoch [1000/1000], Loss: 148268.9219
# Geometry: NDBR20, Epoch [100/1000], Loss: 146151.6719
# Geometry: NDBR20, Epoch [200/1000], Loss: 145834.6250
# Geometry: NDBR20, Epoch [300/1000], Loss: 145767.8906
# Geometry: NDBR20, Epoch [400/1000], Loss: 145688.3906
# Geometry: NDBR20, Epoch [500/1000], Loss: 145586.6719
# Geometry: NDBR20, Epoch [600/1000], Loss: 145429.8750
# Geometry: NDBR20, Epoch [700/1000], Loss: 145155.1094
# Geometry: NDBR20, Epoch [800/1000], Loss: 146724.4531
# Geometry: NDBR20, Epoch [900/1000], Loss: 144406.5156
# Geometry: NDBR20, Epoch [1000/1000], Loss: 144150.9062
# Geometry: NDBR6, Epoch [100/1000], Loss: 147408.3906
# Geometry: NDBR6, Epoch [200/1000], Loss: 147223.5000
# Geometry: NDBR6, Epoch [300/1000], Loss: 146767.1406
# Geometry: NDBR6, Epoch [400/1000], Loss: 145448.8125
# Geometry: NDBR6, Epoch [500/1000], Loss: 144798.7500
# Geometry: NDBR6, Epoch [600/1000], Loss: 143597.7500
# Geometry: NDBR6, Epoch [700/1000], Loss: 143908.2969
# Geometry: NDBR6, Epoch [800/1000], Loss: 142643.3125
# Geometry: NDBR6, Epoch [900/1000], Loss: 143976.4844
# Geometry: NDBR6, Epoch [1000/1000], Loss: 142941.0000
# Geometry: CHD6, Epoch [100/1000], Loss: 141780.5625
# Geometry: CHD6, Epoch [200/1000], Loss: 141369.5938
# Geometry: CHD6, Epoch [300/1000], Loss: 140905.2031
# Geometry: CHD6, Epoch [400/1000], Loss: 140368.8281
# Geometry: CHD6, Epoch [500/1000], Loss: 139737.7500
# Geometry: CHD6, Epoch [600/1000], Loss: 138980.5312
# Geometry: CHD6, Epoch [700/1000], Loss: 138046.8281
# Geometry: CHD6, Epoch [800/1000], Loss: 136848.5312
# Geometry: CHD6, Epoch [900/1000], Loss: 136051.0156
# Geometry: CHD6, Epoch [1000/1000], Loss: 134456.6875
# Predicted parameters for geometry NDBR50:
# [0.0, 953.2559814453125, 0.0, 0.0, 921.5553588867188, 497.9574279785156, 478.4113464355469]
# Predicted parameters for geometry NDBR20:
# [0.0, 815.7456665039062, 0.0, 0.0, 787.780029296875, 425.5714416503906, 409.6593322753906]
# Predicted parameters for geometry NDBR6:
# [0.0, 978.5310668945312, 0.0, 0.0, 946.13916015625, 511.2801208496094, 491.0802307128906]
# Predicted parameters for geometry CHD6:
# [0.0, 979.4594116210938, 0.0, 0.0, 947.04296875, 511.7662353515625, 491.538818359375]

# %%
################################
##                            ##
##      leaky relu            ##
##                            ##
################################


import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch.nn.functional as F


# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
dataPoints = {'NDBR50': 20200, 'NDBR20': 20200, 'NDBR6': 20200, 'CHD6': 20200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a custom neural network model with regularization
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.LeakyReLU(negative_slope=0.01)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.LeakyReLU(negative_slope=0.01)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.relu3 = nn.LeakyReLU(negative_slope=0.01)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.relu4 = nn.LeakyReLU(negative_slope=0.01)
        self.fc5 = nn.Linear(hidden_size4, output_size)
        self.relu_out = nn.ReLU()  #

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)  # Apply ReLU activation with threshold 0
        x = self.relu1(x)
        x = self.fc2(x)
        x = F.relu(x)  # Apply ReLU activation with threshold 0
        x = self.relu2(x)
        x = self.fc3(x)
        x = F.relu(x)  # Apply ReLU activation with threshold 0
        x = self.relu3(x)
        x = self.fc4(x)
        x = F.relu(x)  # Apply ReLU activation with threshold 0
        x = self.relu4(x)
        x = self.fc5(x)
        return x


# Custom loss function with regularization
class CustomMSELoss(nn.Module):
    def __init__(self, lambda_reg):
        super(CustomMSELoss, self).__init__()
        self.lambda_reg = lambda_reg

    def forward(self, outputs, targets, target_values):
        mse_loss = nn.MSELoss()(outputs, targets)
        reg_loss = torch.mean((outputs - target_values) ** 2)
        return mse_loss + self.lambda_reg * reg_loss

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 64  # Number of units in the first hidden layer
hidden_size2 = 64  # Number of units in the second hidden layer
hidden_size3 = 64  # Number of units in the second hidden layer
hidden_size4 = 64  # Number of units in the second hidden layer
output_size = 7    # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size)


# Define a loss function (custom MSE loss with regularization) and an optimizer (e.g., Adam)
criterion = CustomMSELoss(lambda_reg=0.01)  # Adjust lambda_reg as needed
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 1000

target_values = torch.tensor([0.007100880146026611, 1082.105712890625, 0.5171384215354919, 
                              0.23032239079475403, 1017.9251708984375, 490.91802978515625, 475.7492370605469], 
                             dtype=torch.float32)

for geometry in geometries:
    num_samples = min(dataPoints[geometry], len(Y_data))
    X_sample = torch.tensor(X_data[geometry][:num_samples], dtype=torch.float32)
    Y_sample = torch.tensor(Y_data[:num_samples], dtype=torch.float32)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss with regularization
        loss = criterion(outputs, Y_sample, target_values)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Save the trained model
torch.save(model.state_dict(), 'trained_model.pth')

# Load the trained model for prediction
model.load_state_dict(torch.load('trained_model.pth'))
model.eval()  # Set the model to evaluation mode

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)

plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/1000], Loss: 150646.7188
# Geometry: NDBR50, Epoch [200/1000], Loss: 150603.6250
# Geometry: NDBR50, Epoch [300/1000], Loss: 150517.4688
# Geometry: NDBR50, Epoch [400/1000], Loss: 150511.7344
# Geometry: NDBR50, Epoch [500/1000], Loss: 150461.0781
# Geometry: NDBR50, Epoch [600/1000], Loss: 150406.8594
# Geometry: NDBR50, Epoch [700/1000], Loss: 150307.8438
# Geometry: NDBR50, Epoch [800/1000], Loss: 150186.8281
# Geometry: NDBR50, Epoch [900/1000], Loss: 150532.9062
# Geometry: NDBR50, Epoch [1000/1000], Loss: 150232.8438
# Geometry: NDBR20, Epoch [100/1000], Loss: 149274.0312
# Geometry: NDBR20, Epoch [200/1000], Loss: 149152.3125
# Geometry: NDBR20, Epoch [300/1000], Loss: 149033.3594
# Geometry: NDBR20, Epoch [400/1000], Loss: 148851.2969
# Geometry: NDBR20, Epoch [500/1000], Loss: 148560.7500
# Geometry: NDBR20, Epoch [600/1000], Loss: 148082.4688
# Geometry: NDBR20, Epoch [700/1000], Loss: 147174.3594
# Geometry: NDBR20, Epoch [800/1000], Loss: 145676.1875
# Geometry: NDBR20, Epoch [900/1000], Loss: 146175.2031
# Geometry: NDBR20, Epoch [1000/1000], Loss: 145109.1562
# Geometry: NDBR6, Epoch [100/1000], Loss: 148673.3594
# Geometry: NDBR6, Epoch [200/1000], Loss: 148389.6406
# Geometry: NDBR6, Epoch [300/1000], Loss: 147994.7656
# Geometry: NDBR6, Epoch [400/1000], Loss: 147422.1250
# Geometry: NDBR6, Epoch [500/1000], Loss: 146905.3594
# Geometry: NDBR6, Epoch [600/1000], Loss: 146238.7500
# Geometry: NDBR6, Epoch [700/1000], Loss: 161506.2812
# Geometry: NDBR6, Epoch [800/1000], Loss: 145439.9688
# Geometry: NDBR6, Epoch [900/1000], Loss: 144396.5312
# Geometry: NDBR6, Epoch [1000/1000], Loss: 168027.2656
# Geometry: CHD6, Epoch [100/1000], Loss: 139785.0000
# Geometry: CHD6, Epoch [200/1000], Loss: 141988.4531
# Geometry: CHD6, Epoch [300/1000], Loss: 141475.6562
# Geometry: CHD6, Epoch [400/1000], Loss: 140556.4219
# Geometry: CHD6, Epoch [500/1000], Loss: 160577.0312
# Geometry: CHD6, Epoch [600/1000], Loss: 139243.5156
# Geometry: CHD6, Epoch [700/1000], Loss: 139519.8594
# Geometry: CHD6, Epoch [800/1000], Loss: 138593.4219
# Geometry: CHD6, Epoch [900/1000], Loss: 157643.8906
# Geometry: CHD6, Epoch [1000/1000], Loss: 137018.7344
# Predicted parameters for geometry NDBR50:
# [0.5080257654190063, 961.2538452148438, -0.018906069919466972, 0.5069405436515808, 930.0563354492188, 502.1136474609375, 482.07666015625]
# Predicted parameters for geometry NDBR20:
# [0.3461852967739105, 895.3215942382812, -0.24002189934253693, 0.46385353803634644, 865.830078125, 467.9627685546875, 449.72540283203125]
# Predicted parameters for geometry NDBR6:
# [0.5318561792373657, 977.9800415039062, 0.0509515255689621, 0.5141846537590027, 946.367919921875, 510.7716064453125, 490.24951171875]
# Predicted parameters for geometry CHD6:
# [0.5333114862442017, 979.0982666015625, 0.05552630126476288, 0.5148140788078308, 947.4583129882812, 511.35040283203125, 490.79608154296875]

# %%
################################
##                            ##
##           swish            ##
##                            ##
################################


import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch.nn.functional as F


# Define the geometries and yielding indices
geometries = ['NDBR50', 'NDBR20', 'NDBR6', 'CHD6']
dataPoints = {'NDBR50': 20200, 'NDBR20': 20200, 'NDBR6': 20200, 'CHD6': 20200}

# Load data from CSV files
X_files = {
    'NDBR50': "MODEL_DATA/NEWDATA/newData_NDBR50_FD.csv",
    'NDBR20': "MODEL_DATA/NEWDATA/newData_NDBR20_FD.csv",
    'NDBR6': "MODEL_DATA/NEWDATA/newData_NDBR6_FD.csv",
    'CHD6': "MODEL_DATA/NEWDATA/newData_CHD6_FD.csv"
}

Y_file = "MODEL_DATA/NEWDATA/newData_expanded_realHardParam.csv"

X_data = {geometry: pd.read_csv(X_files[geometry], usecols=[0, 1]).values for geometry in geometries}
Y_data = pd.read_csv(Y_file).values

# Define a custom neural network model with regularization
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.swish1 = Swish()  # Custom Swish activation function (you need to implement this)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.swish2 = Swish()
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.swish3 = Swish()
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.swish4 = Swish()
        self.fc5 = nn.Linear(hidden_size4, output_size)
        self.swish_out = Swish()

    def forward(self, x):
        x = self.fc1(x)
        x = self.swish1(x)
        x = self.fc2(x)
        x = self.swish2(x)
        x = self.fc3(x)
        x = self.swish3(x)
        x = self.fc4(x)
        x = self.swish4(x)
        x = self.fc5(x)
        x = self.swish_out(x)
        return x

# Custom Swish activation function
class Swish(nn.Module):
    def forward(self, x):
        return x * torch.sigmoid(x)

# Custom loss function with regularization
class CustomMSELoss(nn.Module):
    def __init__(self, lambda_reg):
        super(CustomMSELoss, self).__init__()
        self.lambda_reg = lambda_reg

    def forward(self, outputs, targets, target_values):
        mse_loss = nn.MSELoss()(outputs, targets)
        reg_loss = torch.mean((outputs - target_values) ** 2)
        return mse_loss + self.lambda_reg * reg_loss

input_size = 2  # Number of input parameters (force and displacement)
hidden_size1 = 64  # Number of units in the first hidden layer
hidden_size2 = 64  # Number of units in the second hidden layer
hidden_size3 = 64  # Number of units in the second hidden layer
hidden_size4 = 64  # Number of units in the second hidden layer
output_size = 7    # Number of output dimensions (c1 to c7)

# Create an instance of the neural network
model = NeuralNetwork(input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, output_size)


# Define a loss function (custom MSE loss with regularization) and an optimizer (e.g., Adam)
criterion = CustomMSELoss(lambda_reg=0.01)  # Adjust lambda_reg as needed
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 1000

target_values = torch.tensor([0.007100880146026611, 1082.105712890625, 0.5171384215354919, 
                              0.23032239079475403, 1017.9251708984375, 490.91802978515625, 475.7492370605469], 
                             dtype=torch.float32)

for geometry in geometries:
    num_samples = min(dataPoints[geometry], len(Y_data))
    X_sample = torch.tensor(X_data[geometry][:num_samples], dtype=torch.float32)
    Y_sample = torch.tensor(Y_data[:num_samples], dtype=torch.float32)

    for epoch in range(num_epochs):
        # Forward pass
        outputs = model(X_sample)

        # Compute the loss with regularization
        loss = criterion(outputs, Y_sample, target_values)

        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % 100 == 0:
            print(f'Geometry: {geometry}, Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Save the trained model
torch.save(model.state_dict(), 'trained_model.pth')

# Load the trained model for prediction
model.load_state_dict(torch.load('trained_model.pth'))
model.eval()  # Set the model to evaluation mode

# Predict parameters for all geometries
predicted_parameters = {}

for geometry in geometries:
    X_test = torch.tensor(X_data[geometry][:1], dtype=torch.float32)
    with torch.no_grad():
        predictions = model(X_test)

    predicted_parameters[geometry] = predictions[0].tolist()

# Print predicted parameters for all geometries
for geometry, params in predicted_parameters.items():
    print(f'Predicted parameters for geometry {geometry}:')
    print(params)

# Visualize 'c1' to 'c7' values for each geometry in a single graph
param_names = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
param_values = [predicted_parameters[geometry] for geometry in geometries]

plt.figure(figsize=(10, 6))
for i, geometry in enumerate(geometries):
    plt.bar(np.arange(len(param_names)) + i * 0.2, param_values[i], width=0.2, label=f'{geometry}')

plt.xlabel('Parameters (c1 to c7)')
plt.ylabel('Values')
plt.title('Comparison of Predicted Hardening Parameters for Different Geometries')
plt.xticks(np.arange(len(param_names)) + 0.2, param_names)

plt.legend()
plt.show()
# Out:
# Geometry: NDBR50, Epoch [100/1000], Loss: 340007.2188
# Geometry: NDBR50, Epoch [200/1000], Loss: 338247.4688
# Geometry: NDBR50, Epoch [300/1000], Loss: 337335.7500
# Geometry: NDBR50, Epoch [400/1000], Loss: 336936.0938
# Geometry: NDBR50, Epoch [500/1000], Loss: 336781.9688
# Geometry: NDBR50, Epoch [600/1000], Loss: 336751.2812
# Geometry: NDBR50, Epoch [700/1000], Loss: 336769.5625
# Geometry: NDBR50, Epoch [800/1000], Loss: 336754.9688
# Geometry: NDBR50, Epoch [900/1000], Loss: 336741.7188
# Geometry: NDBR50, Epoch [1000/1000], Loss: 336728.1562
# Geometry: NDBR20, Epoch [100/1000], Loss: 336434.0312
# Geometry: NDBR20, Epoch [200/1000], Loss: 336420.2188
# Geometry: NDBR20, Epoch [300/1000], Loss: 336405.9375
# Geometry: NDBR20, Epoch [400/1000], Loss: 336391.0625
# Geometry: NDBR20, Epoch [500/1000], Loss: 336375.5625
# Geometry: NDBR20, Epoch [600/1000], Loss: 336359.3438
# Geometry: NDBR20, Epoch [700/1000], Loss: 336342.0938
# Geometry: NDBR20, Epoch [800/1000], Loss: 336323.7812
# Geometry: NDBR20, Epoch [900/1000], Loss: 336304.0625
# Geometry: NDBR20, Epoch [1000/1000], Loss: 336282.5000
# Geometry: NDBR6, Epoch [100/1000], Loss: 337927.0625
# Geometry: NDBR6, Epoch [200/1000], Loss: 337900.0000
# Geometry: NDBR6, Epoch [300/1000], Loss: 337869.5625
# Geometry: NDBR6, Epoch [400/1000], Loss: 337834.9062
# Geometry: NDBR6, Epoch [500/1000], Loss: 337794.4688
# Geometry: NDBR6, Epoch [600/1000], Loss: 337746.3125
# Geometry: NDBR6, Epoch [700/1000], Loss: 337687.4688
# Geometry: NDBR6, Epoch [800/1000], Loss: 337613.1250
# Geometry: NDBR6, Epoch [900/1000], Loss: 337515.7188
# Geometry: NDBR6, Epoch [1000/1000], Loss: 337382.4062
# Geometry: CHD6, Epoch [100/1000], Loss: 337517.1875
# Geometry: CHD6, Epoch [200/1000], Loss: 337475.9062
# Geometry: CHD6, Epoch [300/1000], Loss: 337431.0000
# Geometry: CHD6, Epoch [400/1000], Loss: 337380.8750
# Geometry: CHD6, Epoch [500/1000], Loss: 337324.0000
# Geometry: CHD6, Epoch [600/1000], Loss: 337229.7500
# Geometry: CHD6, Epoch [700/1000], Loss: 337053.9062
# Geometry: CHD6, Epoch [800/1000], Loss: 336885.4062
# Geometry: CHD6, Epoch [900/1000], Loss: 336862.1250
# Geometry: CHD6, Epoch [1000/1000], Loss: 336583.4688
# Predicted parameters for geometry NDBR50:
# [1.7054725885391235, 1138.8538818359375, -9.227790391685175e-20, -4.970704736706466e-09, 1111.1683349609375, 598.1627807617188, 572.06103515625]
# Predicted parameters for geometry NDBR20:
# [2.288804292678833, 948.2850341796875, -1.662574665367564e-16, -4.026028221915112e-08, 924.17236328125, 496.176513671875, 472.30511474609375]
# Predicted parameters for geometry NDBR6:
# [0.6111971735954285, 994.293701171875, -7.516320234517425e-17, -4.54023137308468e-07, 962.93212890625, 519.6149291992188, 498.5726318359375]
# Predicted parameters for geometry CHD6:
# [0.5307564735412598, 979.1055908203125, -1.4900435831325195e-16, -6.953426350264635e-07, 947.388427734375, 511.3309631347656, 490.7840270996094]
