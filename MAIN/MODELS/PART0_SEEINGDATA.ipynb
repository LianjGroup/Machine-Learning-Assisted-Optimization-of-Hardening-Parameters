# %%
import numpy as np

# %%
file_name = "MODEL_DATA/example.npy"

# %%
loaded_data = np.load(file_name, allow_pickle=True)

# %%
loaded_data
# Out:
# array({(('c1', 0.7065706570657065), ('c2', 252.6252625262526), ('c3', 0.06090609060906091), ('c4', 0.45364536453645365), ('c5', 1216.5216521652164), ('c6', 28.9028902890289), ('c7', 435.9435943594359)): {'force': array([2.83444000e+00, 1.32212000e+03, 2.56764000e+03, 3.84633000e+03,
#        5.11905000e+03, 6.17299000e+03, 6.72543000e+03, 6.71392000e+03,
#        6.69084000e+03, 6.70354000e+03, 6.70778000e+03, 6.71589000e+03,
#        6.71655000e+03, 6.70974000e+03, 6.69951000e+03, 6.69413000e+03,
#        6.69225000e+03, 6.69128000e+03, 6.68641000e+03, 6.67979000e+03,
#        6.67272000e+03, 6.66519000e+03, 6.65756000e+03, 6.64992000e+03,
#        6.64278000e+03, 6.63606000e+03, 6.62900000e+03, 6.62081000e+03,
#        6.61197000e+03, 6.60305000e+03, 6.59375000e+03, 6.58365000e+03,
#        6.57280000e+03, 6.56196000e+03, 6.55134000e+03, 6.54074000e+03,
#        6.52981000e+03, 6.51829000e+03, 6.50614000e+03, 6.49351000e+03,
# ...
